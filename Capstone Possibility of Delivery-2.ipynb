# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ## my credentials

# %%
CLIENT_ID = 'VEOZPGP0Z3T2HVH3HE51A03YJM5BGH4HCWBMT4CSSYMHAVEY' # your Foursquare ID
CLIENT_SECRET = 'DZ1F3ILNQU15JLPWSNRMED01MS31GSAEOIPTSFIOJDBNOC3O' # your Foursquare Secret
VERSION = '20200830'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: VEOZPGP0Z3T2HVH3HE51A03YJM5BGH4HCWBMT4CSSYMHAVEY
# CLIENT_SECRET:DZ1F3ILNQU15JLPWSNRMED01MS31GSAEOIPTSFIOJDBNOC3O

# %% [markdown]
# # get location

# %%
address = '225 North Avenue NW, Atlanta, GA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.7722178 -84.3944354

# %%
radius = 5000
LIMIT = 1000

# %% [markdown]
# # explore near location

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=VEOZPGP0Z3T2HVH3HE51A03YJM5BGH4HCWBMT4CSSYMHAVEY&client_secret=DZ1F3ILNQU15JLPWSNRMED01MS31GSAEOIPTSFIOJDBNOC3O&ll=33.7722178,-84.3944354&v=20200830&radius=5000&limit=1000'

# %%
import requests
results = requests.get(url).json()
'There are {} venues arround Georgia Tech.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 venues arround Georgia Tech.'

# %%
items = results['response']['groups'][0]['items']

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng'] + [col for col in dataframe.columns if col.startswith('venue.delivery')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
#dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered = dataframe_filtered.dropna()

dataframe_filtered
# Out:
# <ipython-input-23-90cccf2b28d9>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(items) # flatten JSON
#                            name  \
# 9            Atwoods Pizza Cafe
# 10                     Momonoki
# 11                   Cafe Agora
# 15                Poor Calvin's
# 18      Sweet Hut Bakery & Cafe
# 21                      Bon Ton
# 22     Dancing Goats Coffee Bar
# 24              Savi Provisions
# 28                       Le Fat
# 31  Torched Hop Brewing Company
# 33     Gio's Chicken Amalfitano
# 39                        Tabla
# 43              Red Phone Booth
# 44                Octane Coffee
# 54      The Flying Biscuit Cafe
# 56    Willy's Mexicana Grill #8
# 62                Reuben's Deli
# 70                       Marcel
# 75    Grindhouse Killer Burgers
# 79     Dancing Goats Coffee Bar
# 81     Sweet Auburn Curb Market
# 85             Atlantic Station
# 90                       Gusto!
#
#                                            categories        lat        lng  \
# 9   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  33.777517 -84.387078
# 10  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...  33.779626 -84.390357
# 11  [{'id': '4bf58dd8d48988d1c0941735', 'name': 'M...  33.780932 -84.384460
# 15  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  33.768400 -84.382260
# 18  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  33.780315 -84.384100
# 21  [{'id': '4bf58dd8d48988d14f941735', 'name': 'S...  33.772898 -84.380255
# 22  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  33.780810 -84.386653
# 24  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...  33.781010 -84.384278
# 28  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  33.778169 -84.409113
# 31  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  33.772294 -84.379289
# 33  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  33.784875 -84.405933
# 39  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  33.784531 -84.385067
# 43  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  33.759575 -84.386906
# 44  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  33.779402 -84.410225
# 54  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  33.781880 -84.380340
# 56  [{'id': '4bf58dd8d48988d153941735', 'name': 'B...  33.783976 -84.378824
# 62  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...  33.755687 -84.389442
# 70  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  33.785820 -84.412585
# 75  [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...  33.754240 -84.379855
# 79  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  33.771385 -84.367509
# 81  [{'id': '4bf58dd8d48988d1fa941735', 'name': 'F...  33.754215 -84.379953
# 85  [{'id': '5744ccdfe4b0c0459246b4dc', 'name': 'S...  33.791964 -84.396923
# 90  [{'id': '4bf58dd8d48988d1bd941735', 'name': 'S...  33.791172 -84.406624
#
#          id                                                url     name  \
# 9   2213140  https://www.grubhub.com/restaurant/atwoods-piz...  grubhub
# 10   975665  https://www.grubhub.com/restaurant/momonoki-95...  grubhub
# 11   315820  https://www.grubhub.com/restaurant/cafe-agora-...  grubhub
# 15  2068603  https://www.grubhub.com/restaurant/poor-calvin...  grubhub
# 18   310613  https://www.grubhub.com/restaurant/sweet-hut-b...  grubhub
# 21  2145998  https://www.grubhub.com/restaurant/bon-ton-674...  grubhub
# 22  1489417  https://www.grubhub.com/restaurant/dancing-goa...  grubhub
# 24   322309  https://www.grubhub.com/restaurant/savi-provis...  grubhub
# 28  1490635  https://www.grubhub.com/restaurant/le-fat-935-...  grubhub
# 31  1756454  https://www.grubhub.com/restaurant/torched-hop...  grubhub
# 33   553982  https://www.grubhub.com/restaurant/gios-chicke...  grubhub
# 39   438872  https://www.grubhub.com/restaurant/tabla-77-12...  grubhub
# 43  2278821  https://www.grubhub.com/restaurant/red-phone-b...  grubhub
# 44  1331278  https://www.grubhub.com/restaurant/octane-west...  grubhub
# 54   259168  https://www.grubhub.com/restaurant/the-flying-...  grubhub
# 56  2108964  https://www.grubhub.com/restaurant/willys-mexi...  grubhub
# 62   326067  https://www.grubhub.com/restaurant/reubens-del...  grubhub
# 70  1491406  https://www.grubhub.com/restaurant/marcel-1170...  grubhub
# 75  1065039  https://www.grubhub.com/restaurant/grindhouse-...  grubhub
# 79  1489155  https://www.grubhub.com/restaurant/dancing-goa...  grubhub
# 81  2286859  https://www.grubhub.com/restaurant/sweet-aubur...  grubhub
# 85  2038338  https://www.grubhub.com/restaurant/kilwins-atl...  grubhub
# 90  1974312  https://www.grubhub.com/restaurant/gusto-530-1...  grubhub
#
#                                       prefix     sizes  \
# 9   https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 10  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 11  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 15  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 18  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 21  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 22  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 24  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 28  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 31  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 33  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 39  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 43  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 44  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 54  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 56  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 62  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 70  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 75  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 79  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 81  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 85  https://fastly.4sqi.net/img/general/cap/  [40, 50]
# 90  https://fastly.4sqi.net/img/general/cap/  [40, 50]
#
#                                        name                        id
# 9   /delivery_provider_grubhub_20180129.png  57156db6498e844a5b3b8837
# 10  /delivery_provider_grubhub_20180129.png  5b27d937b3c961002c2af37c
# 11  /delivery_provider_grubhub_20180129.png  4ff5df23e4b02b97149a3a65
# 15  /delivery_provider_grubhub_20180129.png  50a570e38aca7f0bfeca898c
# 18  /delivery_provider_grubhub_20180129.png  5470989c498e14e5b760dfd2
# 21  /delivery_provider_grubhub_20180129.png  58af73c1ac32911213600ed1
# 22  /delivery_provider_grubhub_20180129.png  588e77fc5e7896466a8dc683
# 24  /delivery_provider_grubhub_20180129.png  56030a71498edf3aa79d8a36
# 28  /delivery_provider_grubhub_20180129.png  5398bbb9498ea14ee535bd8f
# 31  /delivery_provider_grubhub_20180129.png  55946a6e498e7b2012f4665c
# 33  /delivery_provider_grubhub_20180129.png  50beb1d1e4b05b9d6a7528e9
# 39  /delivery_provider_grubhub_20180129.png  52a9281311d23c836a98b9b6
# 43  /delivery_provider_grubhub_20180129.png  579621f3498ef64cfb804770
# 44  /delivery_provider_grubhub_20180129.png  4144e300f964a520ad1c1fe3
# 54  /delivery_provider_grubhub_20180129.png  4a4bd8fbf964a520ccac1fe3
# 56  /delivery_provider_grubhub_20180129.png  40e5f700f964a5200f0a1fe3
# 62  /delivery_provider_grubhub_20180129.png  4a89913bf964a5206d0820e3
# 70  /delivery_provider_grubhub_20180129.png  5596db88498e759626b15efe
# 75  /delivery_provider_grubhub_20180129.png  4aabd404f964a5204b5a20e3
# 79  /delivery_provider_grubhub_20180129.png  4fe220fae4b02702d7d533c0
# 81  /delivery_provider_grubhub_20180129.png  4a6a27d2f964a520bbcc1fe3
# 85  /delivery_provider_grubhub_20180129.png  44fc4530f964a52083381fe3
# 90  /delivery_provider_grubhub_20180129.png  5c3b8fd856c89f002be6f4b4

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco



# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
{  
   "__type":"TrafficIncident:http:\/\/schemas.microsoft.com\/search\/local\/ws\/rest\/v1",  
   "point":{  
      "type":"Point",  
      "coordinates":[  
         38.64829,  
         -94.36405  
      ]  
   },
# Out:
#   File "<ipython-input-424-4193b88cb390>", line 9
#     },
#         ^
# SyntaxError: unexpected EOF while parsing

# %%
sudo docker build -t opentraffic/datastore
# Out:
#   File "<ipython-input-427-6d6ceb009185>", line 1
#     sudo docker build -t opentraffic/datastore
#          ^
# SyntaxError: invalid syntax
